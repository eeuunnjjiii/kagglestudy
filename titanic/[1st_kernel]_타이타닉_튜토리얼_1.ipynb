# %% [markdown]
# <a href="https://colab.research.google.com/github/eeuunnjjiii/kagglestudy/blob/main/titanic/%5B1st_kernel%5D_%ED%83%80%EC%9D%B4%ED%83%80%EB%8B%89_%ED%8A%9C%ED%86%A0%EB%A6%AC%EC%96%BC_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 참고 : 타이타닉 튜토리얼 (https://kaggle-kr.tistory.com/17?category=868316, https://kaggle-kr.tistory.com/18?category=868316)

# %% [markdown]
# # 캐글 데이터 연동

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-5a88ae59-3e4e-4175-bc6c-c7dd29f20f11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a88ae59-3e4e-4175-bc6c-c7dd29f20f11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"eunjijeong","key":"29fdf1c9b4bee7ef56c5520fc84d41dc"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning이 발생하지 않도록 해줍니다.
# !chmod 600 ~/.kaggle/kaggle.json
# 내가 참가한 대회 리스트 확인
# !kaggle competitions list
# Out:
# ...
# ref                                                  deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                         2030-07-01 23:59:00  Getting Started     Prizes         57           False
# gan-getting-started                                  2030-07-01 23:59:00  Getting Started     Prizes        116           False
# store-sales-time-series-forecasting                  2030-06-30 23:59:00  Getting Started  Knowledge         35           False
# tpu-getting-started                                  2030-06-03 23:59:00  Getting Started  Knowledge        200           False
# digit-recognizer                                     2030-01-01 00:00:00  Getting Started  Knowledge       1478           False
# ...

# %%
! kaggle competitions download -c titanic
# 압축 파일의 경우
#!unzip train.zip
# Out:
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 22.0MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 23.9MB/s]
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 3.03MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno # 결측치 시각화
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls


# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 1. 데이터셋 확인

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## 1-1. Null data check

# %%
for col in df_train.columns:
  # 컬럼의 결측치 확인({:>10}\t:오른쪽정렬, {:.2}:소수점 둘째자리)
  msg = 'column: {:>10}\t Percent of NaN value; {:.2}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
  print(msg)
# Out:
# column: PassengerId	 Percent of NaN value; 0.0%
# column:   Survived	 Percent of NaN value; 0.0%
# column:     Pclass	 Percent of NaN value; 0.0%
# column:       Name	 Percent of NaN value; 0.0%
# column:        Sex	 Percent of NaN value; 0.0%
# column:        Age	 Percent of NaN value; 2e+01%
# column:      SibSp	 Percent of NaN value; 0.0%
# column:      Parch	 Percent of NaN value; 0.0%
# column:     Ticket	 Percent of NaN value; 0.0%
# column:       Fare	 Percent of NaN value; 0.0%
# column:      Cabin	 Percent of NaN value; 7.7e+01%
# column:   Embarked	 Percent of NaN value; 0.22%

# %%
for col in df_test.columns:
  msg = 'column: {:>10}\t Percent of NaN value; {:.2}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
  print(msg)
# Out:
# column: PassengerId	 Percent of NaN value; 0.0%
# column:     Pclass	 Percent of NaN value; 0.0%
# column:       Name	 Percent of NaN value; 0.0%
# column:        Sex	 Percent of NaN value; 0.0%
# column:        Age	 Percent of NaN value; 2.1e+01%
# column:      SibSp	 Percent of NaN value; 0.0%
# column:      Parch	 Percent of NaN value; 0.0%
# column:     Ticket	 Percent of NaN value; 0.0%
# column:       Fare	 Percent of NaN value; 0.24%
# column:      Cabin	 Percent of NaN value; 7.8e+01%
# column:   Embarked	 Percent of NaN value; 0.0%

# %% [markdown]
# - Train, Test set 모두 age(20%), cabin(80%), Embarked(train 0.22%) null data 존재

# %%
# 결측치 시각화
msno.matrix(df=df_train.iloc[:,:], figsize=(8,8), color=(0.8, 0.5, 0.2) #color로 색상 지정

# %%
msno.bar(df=df_train.iloc[:,:], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# ##1-2. Target label 확인

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True) #explode : 파이차트 간 거리, autopct : 파이차트 안에 표시될 숫자
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# - 38.4%가 살아남음
# - target label 의 분포가 제법 균일(balanced)

# %% [markdown]
# #2. EDA

# %% [markdown]
# ##2-1. Pclass

# %%
# 전체 카운트
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count() #as_index : 인덱스로 사용 (기본값 True)
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
# 생존한 사람의 총합
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
# 시각화
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
## margins=True로 전체까지 출력
## .style.background_gradient(cmap='summer_r')로 색상 추가, 아니면 table 형태로 출력
# Out:
# <style  type="text/css" >
# #T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row0_col0,#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row1_col1,#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_d3a3be82_2a7a_11ec_a0e0_0242ac1c0002row2_col2{
# ...

# %%
# 시각화
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %% [markdown]
# - Pclass가 높을수록 생존률이 높음

# %%
y_position = 1.02 ## title 위치 설정
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# - 클래스가 높을수록 생존확률이 높음
# - 생존에 Pclass가 큰 영향을 미친다고 생각할 수 있으며, 나중에 모델에 이 feature를 사용하는 것이 좋을 것이라 판단할 수 있음

# %% [markdown]
# ##2-2. Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# - 여자가 생존할 확률이 높음

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row0_col0,#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row0_col2,#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row1_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row0_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row1_col0{
#             background-color:  #2c9666;
#             color:  #000000;
#         }#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row1_col2{
#             background-color:  #8bc566;
#             color:  #000000;
#         }#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row2_col0,#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row2_col1,#T_425779c6_2a7c_11ec_a0e0_0242ac1c0002row2_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# - Sex도 모델에 중요한 feature

# %% [markdown]
# ##2-3. Both Sex and Pclass

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5) ## size:시각화 크기, aspect:시각화 비율

# %% [markdown]
# - 모든 클래스에서 female이 생존할 확률이 높음
# - Sex에 관계없이 클래스가 높을수록 생존할 확률이 높음

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass', data=df_train, satureation=.5, size=9, aspect=1) #satureation:채도의 비율

# %% [markdown]
# ##2-4. Age

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
# histogram
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived']==1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived']==0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %% [markdown]
# - 생존자 중 나이가 어린 경우가 많음

# %%
# Age distribution within classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# - class가 높을수록 나이 많은 사람의 비중이 커짐

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# - 나이가 어릴수록 생존률이 높음
# - 나이도 중요한 feature로 사용 가능

# %% [markdown]
# ##2-5. Pclass, Sex, Age

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot('Pclass', 'Age', hue='Survived', data=df_train, sclae='count', split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot('Sex', 'Age', hue='Survived', data=df_train, scale='count', split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# - 왼쪽그림 : Pclass별 Age의 분포와 생존여부 구분 그래프 >  모든 클래스에서 나이가 어릴수록 생존률 높음
# - 오른쪽그림 : Sex별 생존의 분포 그래프 > 여자가 생존률 높음
# - 여성과 아이를 먼저 구조했음을 확인

# %% [markdown]
# #2-6. Embarked

# %%
# 탑승한 항구와 생존률과의 관계
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %% [markdown]
# - C의 생존률이 가장 높은 조금의 차이는 있지만 비슷함

# %%
f, ax = plt.subplots(2, 2, figsize=(20, 15))
sns.countplot('Embarked', data=df_train, ax=ax[0, 0])
ax[0, 0].set_title('(1) No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0, 1])
ax[0, 1].set_title('(2) Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1, 0])
ax[1, 0].set_title('(3) Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1, 1])
ax[1, 1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# - (1) S에서 가장 많은 사람이 탑승
# - (2) C와 Q는 남녀 비율이 비슷했으나, S에서는 남성이 더 많이 탑승
# - (3) 생존확률이 S의 경우 많이 낮음
# - (4) C가 생존률이 높은 것은 클래스 높은 사람이 가장 많이 탔기 때문. 반면 S는 3등급 클래스가 많아 생존률이 낮음

# %% [markdown]
# ##2-7. Family-SibSp(형제 자매)+Parch(부모, 자녀)

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야 하므로 1 더하기
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
# Familysize와 생존과 관계
f, ax = plt.subplots(1, 3, figsize=(40, 10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize', y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize', y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# - (1) 가족 사이즈는 1부터 11까지 있고, 대부분 1명
# - (2), (3) 가족이 4명인 경우 생존률이 가장 높고, 가족수가 작거나 커도 생존률이 적음

# %% [markdown]
# ##2-8. Fare

# %%
# 탑승요금 histogram
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best') # legend 위치

# %% [markdown]
# - 비대칭 분포 > 이대로 모델이 넣으면 모델이 잘못 학습할 수 있음
# - outlier의 영향을 줄이기 위해 log 취하기

# %%
df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean() #testset 결측치 평균값으로 치환

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i>0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i>0 else 0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %% [markdown]
# ## 2-9. Cabin

# %% [markdown]
# - 결측치가 80%에 해당하므로 모델에 불포함

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  FamilySize
# 0            1         0       3  ...   NaN        S           2
# 1            2         1       1  ...   C85        C           2
# 2            3         1       3  ...   NaN        S           1
# 3            4         1       1  ...  C123        S           2
# 4            5         0       3  ...   NaN        S           1
#
# [5 rows x 13 columns]

# %% [markdown]
# ##2-10. Ticket

# %% [markdown]
# - string data

# %%
df_train['Ticket'].value_counts()
# Out:
# CA. 2343         7
# 347082           7
# 1601             7
# CA 2144          6
# 3101295          6
#                 ..
# 250651           1
# 113509           1
# 315086           1
# SC/PARIS 2149    1
# 364498           1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# - 일단 넘기기

# %% [markdown]
# #3. Feature Engineering

# %% [markdown]
# ##3-1. Fill Null

# %% [markdown]
# ###3-1-1. Fill Null in Age using title

# %%
df_train['Initial'] = df_train.Name.str.extract('([A-Za-z]+)\.') #Mr, Ms 등 꺼내기
df_test['Initial']= df_test.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col0,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col1,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col3,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col4,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col5,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col7,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col8,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col12,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col15,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row0_col16,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col2,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col6,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col9,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col10,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col11,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col13,#T_850dc5a6_2a93_11ec_a0e0_0242ac1c0002row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
# ...

# %%
# 성별에 따른 Initial 변환
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)
df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass  ...     Parch      Fare  FamilySize
# Initial                                   ...
# Master    414.975000  0.575000  2.625000  ...  1.375000  3.340710    4.675000
# Miss      411.741935  0.704301  2.284946  ...  0.537634  3.123713    2.236559
# Mr        455.880907  0.162571  2.381853  ...  0.151229  2.651507    1.444234
# Mrs       456.393701  0.795276  1.984252  ...  0.818898  3.443751    2.511811
# Other     564.444444  0.111111  1.666667  ...  0.111111  2.641605    1.222222
#
# [5 rows x 8 columns]

# %% [markdown]
# - 여성과 관계있는 Miss, Mrs 생존률 높음

# %%
df_train.groupby('Initial')['Survived'].mean().plot.bar()

# %%
# Age 평균 값으로 결측치 채우기
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'), 'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age'] = 46

# testset에도 train 값으로 채우기
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mr'),'Age'] = 33
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mrs'),'Age'] = 36
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Master'),'Age'] = 5
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Miss'),'Age'] = 22
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Other'),'Age'] = 46

# %% [markdown]
# ###3-1-2. Fill Null in Embarked

# %%
print('Embarked has ', sum(df_train['Embarked'].isnull()), 'Null values')
# Out:
# Embarked has  2 Null values

# %%
# S에서 가장 많은 탑승객이 있었으므로, S로 치환
df_train['Embarked'].fillna('S', inplace=True)

# %% [markdown]
# ##3-2. Change Age(continuous to categorical)

# %%
# age grouping 1
df_train['Age_cat'] = 0
df_train.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_train.loc[(10 <= df_train['Age']) & (df_train['Age'] < 20), 'Age_cat'] = 1
df_train.loc[(20 <= df_train['Age']) & (df_train['Age'] < 30), 'Age_cat'] = 2
df_train.loc[(30 <= df_train['Age']) & (df_train['Age'] < 40), 'Age_cat'] = 3
df_train.loc[(40 <= df_train['Age']) & (df_train['Age'] < 50), 'Age_cat'] = 4
df_train.loc[(50 <= df_train['Age']) & (df_train['Age'] < 60), 'Age_cat'] = 5
df_train.loc[(60 <= df_train['Age']) & (df_train['Age'] < 70), 'Age_cat'] = 6
df_train.loc[70 <= df_train['Age'], 'Age_cat'] = 7

df_test['Age_cat'] = 0
df_test.loc[df_test['Age'] < 10, 'Age_cat'] = 0
df_test.loc[(10 <= df_test['Age']) & (df_test['Age'] < 20), 'Age_cat'] = 1
df_test.loc[(20 <= df_test['Age']) & (df_test['Age'] < 30), 'Age_cat'] = 2
df_test.loc[(30 <= df_test['Age']) & (df_test['Age'] < 40), 'Age_cat'] = 3
df_test.loc[(40 <= df_test['Age']) & (df_test['Age'] < 50), 'Age_cat'] = 4
df_test.loc[(50 <= df_test['Age']) & (df_test['Age'] < 60), 'Age_cat'] = 5
df_test.loc[(60 <= df_test['Age']) & (df_test['Age'] < 70), 'Age_cat'] = 6
df_test.loc[70 <= df_test['Age'], 'Age_cat'] = 7

# %%
# age grouping 2
def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7    
    
df_train['Age_cat_2'] = df_train['Age'].apply(category_age)

# %%
print('1번 방법, 2번 방법 같은 결과면 True ->', (df_train['Age_cat'] == df_train['Age_cat_2']).all())
# Out:
# 1번 방법, 2번 방법 같은 결과면 True -> False

# %%
df_train.drop(['Age', 'Age_cat_2'], axis=1, inplace=True)
df_test.drop(['Age'], axis=1, inplace=True)

# %% [markdown]
# ##3-3. Change Initail, Embarked and Sex (string to numerical)

# %%
# Initial
df_train['Initial'] = df_train['Initial'].map({'Master':0, 'Miss':1, 'Mr':2, 'Mrs':3, 'Other':4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df_train['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# Embarked
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
# Embarked 결측치 확인
df_train['Embarked'].isnull().any()
# Out:
# False

# %%
# Sex
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %% [markdown]
# - 상관관계 확인
# $$r_{xy} = \frac{Cov(x,y)}{S_{x}S_{y}} = \frac{\frac{1}{n-1}\sum_{i=1}^n(x_{i}-\bar x)(y_{i}-\bar y)}{S_{x}S_{y}}$$

# %%
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat']]

colormap = plt.cm.RdBu
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={'size':16})

del heatmap_data

# %% [markdown]
# - Sex, Pclass가 Survived와 상관관계
# - 강한 상관관계를 가지는 feature는 없음 > 불필요한 feature 없음

# %% [markdown]
# ##3-4. One-hot encoding on Initial and Embarked

# %%
# Initial
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initail') #Prefix:더미변수 컬럼명
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Initail_2  Initail_3  Initail_4
# 0            1         0       3  ...         1          0          0
# 1            2         1       1  ...         0          1          0
# 2            3         1       3  ...         0          0          0
# 3            4         1       1  ...         0          1          0
# 4            5         0       3  ...         1          0          0
#
# [5 rows x 18 columns]

# %%
# Embarked
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %% [markdown]
# ##3-5. Drop Columns

# %%
# 불필요한 특성 삭제
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name',  'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex  ...  Embarked_0  Embarked_1  Embarked_2
# 0         0       3    1  ...           0           0           1
# 1         1       1    0  ...           1           0           0
# 2         1       3    0  ...           0           0           1
# 3         1       1    0  ...           0           0           1
# 4         0       3    1  ...           0           0           1
#
# [5 rows x 14 columns]

# %%
df_test.head()
# Out:
#    Pclass  Sex      Fare  ...  Embarked_0  Embarked_1  Embarked_2
# 0       3    1  2.057860  ...           0           1           0
# 1       3    0  1.945910  ...           0           0           1
# 2       2    1  2.270836  ...           0           1           0
# 3       3    1  2.159003  ...           0           0           1
# 4       3    0  2.508582  ...           0           0           1
#
# [5 rows x 13 columns]

# %% [markdown]
# - Survived 컬럼을 제외하고 모두 동일

# %% [markdown]
# #4. Building machine learning model and prediction using the trained model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##4-1. Preparation - Split dataset into train, valid, test set

# %%
# 데이터 분리
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=2018)

# %% [markdown]
# ##4-2. Model generation and prediction

# %%
model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
# 성능 확인
print('총 {}명 중 {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100*metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 268명 중 82.46% 정확도로 생존을 맞춤

# %% [markdown]
# ##4-3. Feature Importance

# %%
from pandas import Series

feature_importance = model.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

# %%
plt.figure(figsize=(8, 8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# - 모델에서 가장 큰 영향력을 가지는 feature는 Fare, Initial_2, Age_cat, Pclass 순
# - Fare가 중요한 feature라고 판단 내릴 수 있지만, 통계적으로 더욱 면밀히 살펴봐야함

# %% [markdown]
# ##4-4. Prediction on Test set

# %%
submission = pd.read_csv('gender_submission.csv')

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
prediction = model.predict(X_test)
submission['Survived'] = prediction

# %%
submission.to_csv('submission.csv', index=False)
